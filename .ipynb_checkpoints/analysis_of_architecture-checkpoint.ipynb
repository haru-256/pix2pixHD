# %%
import torch
from models.pix2pixHD_model import Pix2PixHDModel
import easydict
from models import networks

# %%
model = Pix2PixHDModel()

# %%
opt = easydict.EasyDict({
    'name': 'label2city',
    'gpu_ids': '0',
    'norm': 'instance',
    'data_type': 32,
    'verbose': True,
    'batchSize': 1,
    'loadSize': 1024,
    'fineSize': 512,
    'label_nc': 35,
    'input_nc': 3,
    'output_nc': 3,
    'netG': 'global',
    'ngf': 64,
    'n_downsample_global': 4,
    'n_blocks_global': 9,
    'n_blocks_local': 3,
    'n_local_enhancers': 1,
    'niter_fix_global': 0,
    'feat_num': 3,
    'n_downsample_E': 4,
    'nef': 16,
    'n_clusters': 10,
})

# %%
generator = networks.define_G(
    opt.label_nc,
    opt.output_nc,
    opt.ngf,
    opt.netG,
    opt.n_downsample_global,
    opt.n_blocks_global,
    opt.n_local_enhancers,
    opt.n_blocks_local,
    opt.norm,
    gpu_ids='')
# Out:
# GlobalGenerator(
#   (model): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(35, 64, kernel_size=(7, 7), stride=(1, 1))
#     (2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (3): ReLU(inplace)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (11): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (12): ReLU(inplace)
#     (13): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
# ...

# %%
opt.label_nc
# Out:
# 35

# %%
opt.n_local_enhancers
# Out:
# 1

# %%
opt.netG
# Out:
# 'global'

# %%
networks.print_network(generator)
# Out:
# GlobalGenerator(
#   (model): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(35, 64, kernel_size=(7, 7), stride=(1, 1))
#     (2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (3): ReLU(inplace)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (11): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (12): ReLU(inplace)
#     (13): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
# ...

# %%
generator = networks.define_G(
    opt.label_nc,
    opt.output_nc,
    32,
    'local',
    opt.n_downsample_global,
    opt.n_blocks_global,
    opt.n_local_enhancers,
    opt.n_blocks_local,
    opt.norm,
    gpu_ids='')
# Out:
# LocalEnhancer(
#   (model): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(35, 64, kernel_size=(7, 7), stride=(1, 1))
#     (2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (3): ReLU(inplace)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (11): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (12): ReLU(inplace)
#     (13): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
# ...

# %%
opt.n_blocks_local, opt.n_local_enhancers
# Out:
# (3, 1)

# %%
networks.LocalEnhancer(64, 64)
# Out:
# LocalEnhancer(
#   (model): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(64, 64, kernel_size=(7, 7), stride=(1, 1))
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (11): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace)
#     (13): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-6a1284577a36> in <module>
# ----> 1 a[0]
#
# TypeError: 'LocalEnhancer' object does not support indexing
